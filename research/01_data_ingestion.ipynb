# %%
import os

# %%
# %pwd

# %%
os.chdir("../")

# %%
# %pwd

# %%
from dataclasses import dataclass
from pathlib import Path


@dataclass(frozen=True)
class DataIngestionConfig:
    root_dir: Path
    source_URL: str
    local_data_file: Path
    unzip_dir: Path

# %%
from cnnClassifier.constants import *
from cnnClassifier.utils.common import read_yaml, create_directories

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)

        create_directories([self.config.artifacts_root])


    
    def get_data_ingestion_config(self) -> DataIngestionConfig:
        config = self.config.data_ingestion

        create_directories([config.root_dir])

        data_ingestion_config = DataIngestionConfig(
            root_dir=config.root_dir,
            source_URL=config.source_URL,
            local_data_file=config.local_data_file,
            unzip_dir=config.unzip_dir 
        )

        return data_ingestion_config

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)

        create_directories([self.config.artifacts_root])


    
    def get_data_ingestion_config(self) -> DataIngestionConfig:
        config = self.config.data_ingestion

        create_directories([config.root_dir])

        data_ingestion_config = DataIngestionConfig(
            root_dir=config.root_dir,
            source_URL=config.source_URL,
            local_data_file=config.local_data_file,
            unzip_dir=config.unzip_dir 
        )

        return data_ingestion_config

# %%
import sys
from pathlib import Path

sys.path.append(str(Path().resolve() / "src"))

# %%
sys.path.append("../src")

# %%
from cnnClassifier.constants import CONFIG_FILE_PATH, PARAMS_FILE_PATH

# %%
sys.path.append("../src")

# %%
import sys
from pathlib import Path

sys.path.append(str(Path().resolve().parents[0] / "src"))

# %%
import cnnClassifier.constants as c

# %%
dir(c)

# %%
from cnnClassifier.constants import CONFIG_FILE_PATH, PARAMS_FILE_PATH
print(CONFIG_FILE_PATH)
print(PARAMS_FILE_PATH)

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)

        create_directories([self.config.artifacts_root])


    
    def get_data_ingestion_config(self) -> DataIngestionConfig:
        config = self.config.data_ingestion

        create_directories([config.root_dir])

        data_ingestion_config = DataIngestionConfig(
            root_dir=config.root_dir,
            source_URL=config.source_URL,
            local_data_file=config.local_data_file,
            unzip_dir=config.unzip_dir 
        )

        return data_ingestion_config

# %%
from dataclasses import dataclass
from pathlib import Path


@dataclass(frozen=True)
class DataIngestionConfig:
    root_dir: Path
    source_URL: str
    local_data_file: Path
    unzip_dir: Path

# %%
    def __init__(
        self,
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)

        create_directories([self.config.artifacts_root])


    
    def get_data_ingestion_config(self) -> DataIngestionConfig:
        config = self.config.data_ingestion

        create_directories([config.root_dir])

        data_ingestion_config = DataIngestionConfig(
            root_dir=config.root_dir,
            source_URL=config.source_URL,
            local_data_file=config.local_data_file,
            unzip_dir=config.unzip_dir 
        )

        return data_ingestion_config

# %%
import os
import zipfile
import gdown
from cnnClassifier import logger
from cnnClassifier.utils.common import get_size

# %%
class DataIngestion:
    def __init__(self, config: DataIngestionConfig):
        self.config = config

    
    def download_file(self)-> str:
        '''
        Fetch data from the url
        '''

        try: 
            dataset_url = self.config.source_URL
            zip_download_dir = self.config.local_data_file
            os.makedirs("artifacts/data_ingestion", exist_ok=True)
            logger.info(f"Downloading data from {dataset_url} into file {zip_download_dir}")

            file_id = dataset_url.split("/")[-2]
            prefix = 'https://drive.google.com/uc?/export=download&id='
            gdown.download(prefix+file_id,zip_download_dir)

            logger.info(f"Downloaded data from {dataset_url} into file {zip_download_dir}")

        except Exception as e:
            raise e
        
    

    def extract_zip_file(self):
        """
        zip_file_path: str
        Extracts the zip file into the data directory
        Function returns None
        """
        unzip_path = self.config.unzip_dir
        os.makedirs(unzip_path, exist_ok=True)
        with zipfile.ZipFile(self.config.local_data_file, 'r') as zip_ref:
            zip_ref.extractall(unzip_path)

# %%
from dataclasses import dataclass
from pathlib import Path


@dataclass(frozen=True)
class DataIngestionConfig:
    root_dir: Path
    source_URL: str
    local_data_file: Path
    unzip_dir: Path

# %%
class DataIngestion:
    def __init__(self, config: DataIngestionConfig):
        self.config = config

    
    def download_file(self)-> str:
        '''
        Fetch data from the url
        '''

        try: 
            dataset_url = self.config.source_URL
            zip_download_dir = self.config.local_data_file
            os.makedirs("artifacts/data_ingestion", exist_ok=True)
            logger.info(f"Downloading data from {dataset_url} into file {zip_download_dir}")

            file_id = dataset_url.split("/")[-2]
            prefix = 'https://drive.google.com/uc?/export=download&id='
            gdown.download(prefix+file_id,zip_download_dir)

            logger.info(f"Downloaded data from {dataset_url} into file {zip_download_dir}")

        except Exception as e:
            raise e
        
    

    def extract_zip_file(self):
        """
        zip_file_path: str
        Extracts the zip file into the data directory
        Function returns None
        """
        unzip_path = self.config.unzip_dir
        os.makedirs(unzip_path, exist_ok=True)
        with zipfile.ZipFile(self.config.local_data_file, 'r') as zip_ref:
            zip_ref.extractall(unzip_path)

# %%
try:
    config = ConfigurationManager()
    data_ingestion_config = config.get_data_ingestion_config()
    data_ingestion = DataIngestion(config=data_ingestion_config)
    data_ingestion.download_file()
    data_ingestion.extract_zip_file()
except Exception as e:
    raise e

# %%
from src.cnnClassifier.config.configuration import ConfigurationManager

# %%
from cnnClassifier.constants import *
from cnnClassifier.utils.common import read_yaml, create_directories

# %%
try:
    config = ConfigurationManager()
    data_ingestion_config = config.get_data_ingestion_config()
    data_ingestion = DataIngestion(config=data_ingestion_config)
    data_ingestion.download_file()
    data_ingestion.extract_zip_file()
except Exception as e:
    raise e

# %%
import sys
import os

ROOT_DIR = os.path.abspath("..")   # goes to project root
sys.path.append(ROOT_DIR)

print(ROOT_DIR)

# %%
from src.cnnClassifier.config.configuration import ConfigurationManager

# %%
try:
    config = ConfigurationManager()
    data_ingestion_config = config.get_data_ingestion_config()
    data_ingestion = DataIngestion(config=data_ingestion_config)
    data_ingestion.download_file()
    data_ingestion.extract_zip_file()
except Exception as e:
    raise e

# %%
import src.cnnClassifier.config.configuration as config_module

print(dir(config_module))

# %%
import sys
import os

sys.path.append(os.path.abspath("../src"))

# %%
from cnnClassifier.config.configuration import ConfigurationManager

# %%
from cnnClassifier.config.configuration import ConfigurationManager

# %%
config = ConfigurationManager()

print(config.config)
print(config.params)

# %%
config = ConfigurationManager()
print(config.config)
print(config.params)

# %%
try:
    config = ConfigurationManager()
    data_ingestion_config = config.get_data_ingestion_config()
    data_ingestion = DataIngestion(config=data_ingestion_config)
    data_ingestion.download_file()
    data_ingestion.extract_zip_file()
except Exception as e:
    raise e

# %%
try:
    config = ConfigurationManager()
    data_ingestion_config = config.get_data_ingestion_config()
    data_ingestion = DataIngestion(config=data_ingestion_config)
    data_ingestion.download_file()
    data_ingestion.extract_zip_file()
except Exception as e:
    raise e

# %%
config = ConfigurationManager()
print(config.config)
print(config.params)

# %%
import sys
import os

sys.path.append(os.path.abspath("../src"))

# %%
from cnnClassifier.config.configuration import ConfigurationManager

# %%
config = ConfigurationManager()
print(config.config)
print(config.params)

# %%
from cnnClassifier.constants import CONFIG_FILE_PATH
print(CONFIG_FILE_PATH)

# %%
from cnnClassifier.constants import CONFIG_FILE_PATH
print(CONFIG_FILE_PATH)

# %%
from cnnClassifier.config.configuration import ConfigurationManager

config = ConfigurationManager()
print(config.config)
print(config.params)

# %%
from cnnClassifier.config.configuration import ConfigurationManager

config = ConfigurationManager()
print(config.params.LEARNING_RATE)
print(type(config.params.LEARNING_RATE))

# %%
try:
    config = ConfigurationManager()
    data_ingestion_config = config.get_data_ingestion_config()
    data_ingestion = DataIngestion(config=data_ingestion_config)
    data_ingestion.download_file()
    data_ingestion.extract_zip_file()
except Exception as e:
    raise e
# Out:
# [2026-02-18 22:11:49,785: INFO: common: yaml file: C:\Users\kushagra\Kidney-Disease_Classification-MLflow-DVC\config\config.yaml loaded successfully]
# ---------------------------------------------------------------------------
# BoxValueError                             Traceback (most recent call last)
# File ~\Kidney-Disease_Classification-MLflow-DVC\src\cnnClassifier\utils\common.py:33, in read_yaml(path_to_yaml)
#      32         logger.info(f"yaml file: {path_to_yaml} loaded successfully")
# ---> 33         return ConfigBox(content)
#      34 except BoxValueError:
#
# File d:\anoconda3\envs\kidney\lib\site-packages\box\box.py:259, in box.box.Box.__init__()
#
# BoxValueError: First argument must be mapping or iterable
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 8
#       6     data_ingestion.extract_zip_file()
#       7 except Exception as e:
# ----> 8     raise e
#
# Cell In[2], line 2
#       1 try:
# ----> 2     config = ConfigurationManager()
#       3     data_ingestion_config = config.get_data_ingestion_config()
#       4     data_ingestion = DataIngestion(config=data_ingestion_config)
#
# File ~\Kidney-Disease_Classification-MLflow-DVC\src\cnnClassifier\config\configuration.py:16, in ConfigurationManager.__init__(self, config_filepath, params_filepath)
#      11 def __init__(
#      12     self,
#      13     config_filepath = CONFIG_FILE_PATH,
#      14     params_filepath = PARAMS_FILE_PATH):
# ---> 16     self.config = read_yaml(config_filepath)
#      17     self.params = read_yaml(params_filepath)
#      19     create_directories([self.config.artifacts_root])
#
# File d:\anoconda3\envs\kidney\lib\site-packages\ensure\main.py:849, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     841         msg = (
#     842             "Argument {arg} of type {valt} to {f} "
#     843             "does not match annotation type {t}"
#     844         )
#     845         raise EnsureError(msg.format(
#     846             arg=arg, f=self.f, t=templ, valt=type(value)
#     847         ))
# --> 849 return_val = self.f(*args, **kwargs)
#     850 if not isinstance(return_val, self.return_templ):
#     851     msg = (
#     852         "Return value of {f} of type {valt} "
#     853         "does not match annotation type {t}"
#     854     )
#
# File ~\Kidney-Disease_Classification-MLflow-DVC\src\cnnClassifier\utils\common.py:35, in read_yaml(path_to_yaml)
#      33         return ConfigBox(content)
#      34 except BoxValueError:
# ---> 35     raise ValueError("yaml file is empty")
#      36 except Exception as e:
#      37     raise e
#
# ValueError: yaml file is empty

# %%
class DataIngestion:
    def __init__(self, config: DataIngestionConfig):
        self.config = config

    
    def download_file(self)-> str:
        '''
        Fetch data from the url
        '''

        try: 
            dataset_url = self.config.source_URL
            zip_download_dir = self.config.local_data_file
            os.makedirs("artifacts/data_ingestion", exist_ok=True)
            logger.info(f"Downloading data from {dataset_url} into file {zip_download_dir}")

            file_id = dataset_url.split("/")[-2]
            prefix = 'https://drive.google.com/uc?/export=download&id='
            gdown.download(prefix+file_id,zip_download_dir)

            logger.info(f"Downloaded data from {dataset_url} into file {zip_download_dir}")

        except Exception as e:
            raise e
        
    

    def extract_zip_file(self):
        """
        zip_file_path: str
        Extracts the zip file into the data directory
        Function returns None
        """
        unzip_path = self.config.unzip_dir
        os.makedirs(unzip_path, exist_ok=True)
        with zipfile.ZipFile(self.config.local_data_file, 'r') as zip_ref:
            zip_ref.extractall(unzip_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 class DataIngestion:
#       2     def __init__(self, config: DataIngestionConfig):
#       3         self.config = config
#
# Cell In[3], line 2, in DataIngestion()
#       1 class DataIngestion:
# ----> 2     def __init__(self, config: DataIngestionConfig):
#       3         self.config = config
#       6     def download_file(self)-> str:
#
# NameError: name 'DataIngestionConfig' is not defined

# %%
from dataclasses import dataclass
from pathlib import Path


@dataclass(frozen=True)
class DataIngestionConfig:
    root_dir: Path
    source_URL: str
    local_data_file: Path
    unzip_dir: Path

# %%
class DataIngestion:
    def __init__(self, config: DataIngestionConfig):
        self.config = config

    
    def download_file(self)-> str:
        '''
        Fetch data from the url
        '''

        try: 
            dataset_url = self.config.source_URL
            zip_download_dir = self.config.local_data_file
            os.makedirs("artifacts/data_ingestion", exist_ok=True)
            logger.info(f"Downloading data from {dataset_url} into file {zip_download_dir}")

            file_id = dataset_url.split("/")[-2]
            prefix = 'https://drive.google.com/uc?/export=download&id='
            gdown.download(prefix+file_id,zip_download_dir)

            logger.info(f"Downloaded data from {dataset_url} into file {zip_download_dir}")

        except Exception as e:
            raise e
        
    

    def extract_zip_file(self):
        """
        zip_file_path: str
        Extracts the zip file into the data directory
        Function returns None
        """
        unzip_path = self.config.unzip_dir
        os.makedirs(unzip_path, exist_ok=True)
        with zipfile.ZipFile(self.config.local_data_file, 'r') as zip_ref:
            zip_ref.extractall(unzip_path)

# %%
from cnnClassifier.constants import *
from cnnClassifier.utils.common import read_yaml, create_directories

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)

        create_directories([self.config.artifacts_root])


    
    def get_data_ingestion_config(self) -> DataIngestionConfig:
        config = self.config.data_ingestion

        create_directories([config.root_dir])

        data_ingestion_config = DataIngestionConfig(
            root_dir=config.root_dir,
            source_URL=config.source_URL,
            local_data_file=config.local_data_file,
            unzip_dir=config.unzip_dir 
        )

        return data_ingestion_config

# %%
try:
    config = ConfigurationManager()
    data_ingestion_config = config.get_data_ingestion_config()
    data_ingestion = DataIngestion(config=data_ingestion_config)
    data_ingestion.download_file()
    data_ingestion.extract_zip_file()
except Exception as e:
    raise e
# Out:
# [2026-02-18 22:14:48,616: INFO: common: yaml file: C:\Users\kushagra\Kidney-Disease_Classification-MLflow-DVC\config\config.yaml loaded successfully]
# ---------------------------------------------------------------------------
# BoxValueError                             Traceback (most recent call last)
# File ~\Kidney-Disease_Classification-MLflow-DVC\src\cnnClassifier\utils\common.py:33, in read_yaml(path_to_yaml)
#      32         logger.info(f"yaml file: {path_to_yaml} loaded successfully")
# ---> 33         return ConfigBox(content)
#      34 except BoxValueError:
#
# File d:\anoconda3\envs\kidney\lib\site-packages\box\box.py:259, in box.box.Box.__init__()
#
# BoxValueError: First argument must be mapping or iterable
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 8
#       6     data_ingestion.extract_zip_file()
#       7 except Exception as e:
# ----> 8     raise e
#
# Cell In[8], line 2
#       1 try:
# ----> 2     config = ConfigurationManager()
#       3     data_ingestion_config = config.get_data_ingestion_config()
#       4     data_ingestion = DataIngestion(config=data_ingestion_config)
#
# Cell In[7], line 7, in ConfigurationManager.__init__(self, config_filepath, params_filepath)
#       2 def __init__(
#       3     self,
#       4     config_filepath = CONFIG_FILE_PATH,
#       5     params_filepath = PARAMS_FILE_PATH):
# ----> 7     self.config = read_yaml(config_filepath)
#       8     self.params = read_yaml(params_filepath)
#      10     create_directories([self.config.artifacts_root])
#
# File d:\anoconda3\envs\kidney\lib\site-packages\ensure\main.py:849, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     841         msg = (
#     842             "Argument {arg} of type {valt} to {f} "
#     843             "does not match annotation type {t}"
#     844         )
#     845         raise EnsureError(msg.format(
#     846             arg=arg, f=self.f, t=templ, valt=type(value)
#     847         ))
# --> 849 return_val = self.f(*args, **kwargs)
#     850 if not isinstance(return_val, self.return_templ):
#     851     msg = (
#     852         "Return value of {f} of type {valt} "
#     853         "does not match annotation type {t}"
#     854     )
#
# File ~\Kidney-Disease_Classification-MLflow-DVC\src\cnnClassifier\utils\common.py:35, in read_yaml(path_to_yaml)
#      33         return ConfigBox(content)
#      34 except BoxValueError:
# ---> 35     raise ValueError("yaml file is empty")
#      36 except Exception as e:
#      37     raise e
#
# ValueError: yaml file is empty

# %%
from cnnClassifier.constants import CONFIG_FILE_PATH, PARAMS_FILE_PATH

print("CONFIG PATH:", CONFIG_FILE_PATH)
print("PARAMS PATH:", PARAMS_FILE_PATH)

print("\nCONFIG FILE CONTENT:\n")
print(open(CONFIG_FILE_PATH).read())

print("\nPARAMS FILE CONTENT:\n")
print(open(PARAMS_FILE_PATH).read())
# Out:
# CONFIG PATH: C:\Users\kushagra\Kidney-Disease_Classification-MLflow-DVC\config\config.yaml
# PARAMS PATH: C:\Users\kushagra\Kidney-Disease_Classification-MLflow-DVC\params.yaml
#
# CONFIG FILE CONTENT:
#
# artifacts_root: artifacts
#
#
# data_ingestion:
#   root_dir: artifacts/data_ingestion
#   source_URL: https://drive.google.com/file/d/1-0aZuQfEkJqCR4Wnuwuv6pmI5QAJZYm6/view?usp=sharing
#   local_data_file: artifacts/data_ingestion/data.zip
#   unzip_dir: artifacts/data_ingestion
#
#
# prepare_base_model:
#   root_dir: artifacts/prepare_base_model
#   base_model_path: artifacts/prepare_base_model/base_model.h5
#   updated_base_model_path: artifacts/prepare_base_model/base_model_updated.h5
#
#
#
#
# training:
#   root_dir: artifacts/training
#   trained_model_path: artifacts/training/model.h5
#
# PARAMS FILE CONTENT:
#
# key:val

# %%
from cnnClassifier.constants import PARAMS_FILE_PATH
print(open(PARAMS_FILE_PATH).read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 from cnnClassifier.constants import PARAMS_FILE_PATH
# ----> 2 print(open(PARAMS_FILE_PATH).read())
#
# File d:\anoconda3\envs\kidney\lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'params.yaml'

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\kushagra\Kidney-Disease_Classification-MLflow-DVC\research

# %%
import os
os.chdir("..")
print(os.getcwd())
# Out:
# c:\Users\kushagra\Kidney-Disease_Classification-MLflow-DVC

# %%
from cnnClassifier.constants import PARAMS_FILE_PATH
print(PARAMS_FILE_PATH)
print(open(PARAMS_FILE_PATH).read())
# Out:
# params.yaml
# IMAGE_SIZE: [224, 224, 3]
# BATCH_SIZE: 16
# EPOCHS: 1
# LEARNING_RATE: 0.01
# INCLUDE_TOP: false
# WEIGHTS: imagenet
# CLASSES: 2
# AUGMENTATION: true

# %%
from cnnClassifier.config.configuration import ConfigurationManager
from cnnClassifier.components.data_ingestion import DataIngestion

config = ConfigurationManager()

data_ingestion_config = config.get_data_ingestion_config()
data_ingestion = DataIngestion(config=data_ingestion_config)

data_ingestion.download_file()
data_ingestion.extract_zip_file()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 from cnnClassifier.config.configuration import ConfigurationManager
# ----> 2 from cnnClassifier.components.data_ingestion import DataIngestion
#       4 config = ConfigurationManager()
#       6 data_ingestion_config = config.get_data_ingestion_config()
#
# ModuleNotFoundError: No module named 'cnnClassifier.components.data_ingestion'

# %%
from cnnClassifier.components.data_ingestion import DataIngestion

# %%
config = ConfigurationManager()
data_ingestion_config = config.get_data_ingestion_config()

data_ingestion = DataIngestion(config=data_ingestion_config)
data_ingestion.download_file()
data_ingestion.extract_zip_file()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 config = ConfigurationManager()
#       2 data_ingestion_config = config.get_data_ingestion_config()
#       4 data_ingestion = DataIngestion(config=data_ingestion_config)
#
# NameError: name 'ConfigurationManager' is not defined

# %%
from cnnClassifier.constants import PARAMS_FILE_PATH
print(PARAMS_FILE_PATH)
print(open(PARAMS_FILE_PATH).read())
# Out:
# params.yaml
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 from cnnClassifier.constants import PARAMS_FILE_PATH
#       2 print(PARAMS_FILE_PATH)
# ----> 3 print(open(PARAMS_FILE_PATH).read())
#
# File d:\anoconda3\envs\kidney\lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'params.yaml'

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\kushagra\Kidney-Disease_Classification-MLflow-DVC\research

# %%
import os
os.chdir("..")
print(os.getcwd())
# Out:
# c:\Users\kushagra\Kidney-Disease_Classification-MLflow-DVC

# %%
from cnnClassifier.constants import PARAMS_FILE_PATH
print(PARAMS_FILE_PATH)
print(open(PARAMS_FILE_PATH).read())
# Out:
# params.yaml
# IMAGE_SIZE: [224, 224, 3]
# BATCH_SIZE: 16
# EPOCHS: 1
# LEARNING_RATE: 0.01
# INCLUDE_TOP: false
# WEIGHTS: imagenet
# CLASSES: 2
# AUGMENTATION: true

# %%
from cnnClassifier.config.configuration import ConfigurationManager
from cnnClassifier.components.data_ingestion import DataIngestion

config = ConfigurationManager()

data_ingestion_config = config.get_data_ingestion_config()
data_ingestion = DataIngestion(config=data_ingestion_config)

data_ingestion.download_file()
data_ingestion.extract_zip_file()
# Out:
# [2026-02-18 22:28:13,961: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2026-02-18 22:28:13,973: INFO: common: yaml file: params.yaml loaded successfully]
# [2026-02-18 22:28:13,976: INFO: common: created directory at: artifacts]
# [2026-02-18 22:28:13,983: INFO: common: created directory at: artifacts/data_ingestion]
# [2026-02-18 22:28:13,988: INFO: data_ingestion: Downloading data from https://drive.google.com/file/d/1-0aZuQfEkJqCR4Wnuwuv6pmI5QAJZYm6/view?usp=sharing into file artifacts/data_ingestion/data.zip]
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1-0aZuQfEkJqCR4Wnuwuv6pmI5QAJZYm6
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1-0aZuQfEkJqCR4Wnuwuv6pmI5QAJZYm6&confirm=t&uuid=4f970764-8bca-4514-b790-088d757160ff
# To: c:\Users\kushagra\Kidney-Disease_Classification-MLflow-DVC\artifacts\data_ingestion\data.zip
# 100%|██████████| 1.63G/1.63G [01:36<00:00, 16.9MB/s]
# [2026-02-18 22:29:54,679: INFO: data_ingestion: Downloaded data from https://drive.google.com/file/d/1-0aZuQfEkJqCR4Wnuwuv6pmI5QAJZYm6/view?usp=sharing into file artifacts/data_ingestion/data.zip]
